# %% [markdown]
# <a href="https://colab.research.google.com/github/Guliko24/PubMed_Fetch/blob/main/How_to_clone_Git_to_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Part 2: How to LOAD them into ANY new Colab Notebook
# Whenever you start a new Colab session (or if the runtime resets), you just need to "clone" (download) your repository directly into Colab.
# In your new Colab notebook, run this exact code in the very first cell:

# %%
# 1. Clone your entire GitHub repository into the Colab environment
# !git clone https://github.com/YOUR_USERNAME/scientific-discovery-engine.git

# 2. Tell Python to look inside that folder for your custom files
import sys
sys.path.append('/content/scientific-discovery-engine')

# 3. Install your dependencies
# !pip install -r /content/scientific-discovery-engine/requirements.txt --quiet

# 4. Now you can import your functions!
from search_utils import load_or_fetch_pubmed_data, build_bm25_index, search_bm25, generate_embeddings, search_vectors

print("✅ Project loaded from GitHub successfully!")
